# %%
import nltk
from nltk.stem import WordNetLemmatizer

# Download the required WordNet data
nltk.download('wordnet')
nltk.download('omw-1.4')  # Optional: for additional wordnet data

# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize the word "running" with POS as verb
lemmatized_word = lemmatizer.lemmatize("running", pos="v")
print(lemmatized_word)
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Amrut
# [nltk_data]     Nikam\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to C:\Users\Amrut
# [nltk_data]     Nikam\AppData\Roaming\nltk_data...
# run
