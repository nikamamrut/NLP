# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Amrut
# [nltk_data]     Nikam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Amrut Nikam\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
def pos_tagging(text):
    """perform pos tagging on the input text"""
    #tokenize the text into the words
    words=nltk.word_tokenize(text)
    pos_tags=nltk.pos_tag(words)
    return pos_tags

# %%
text = "The quick brown fox jumps over the lazy dog."
tags = pos_tagging(text)
print(tags)
# Out:
# [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('.', '.')]
